# %% [markdown]
# # Improving the accuracy of the ANN(Artificial Neural Network) preventing model from overfitting
# ## Early Stopping

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.datasets import make_circles
from mlxtend.plotting import plot_decision_regions
import tensorflow
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.callbacks import EarlyStopping
from pylab import rcParams

# %%
x, y = make_circles(n_samples=100, noise=0.1, random_state=1)

# %%
sns.scatterplot(x=x[:,0], y=x[:,1], hue=y)
plt.show()

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
model = Sequential()

model.add(Dense(256, input_dim=2, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
# Out:
# f:\Windows 10\Python Files\Data Science\py_venv\Lib\site-packages\keras\src\layers\core\dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(loss='binary_crossentropy',optimizer='adam', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 256)            │           768 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │           257 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,025 (4.00 KB)
#  Trainable params: 1,025 (4.00 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
callback = EarlyStopping(
    monitor='val_loss',
    min_delta=0.00001,
    patience=50,
    verbose=1,
    mode='auto',
    baseline=None,
    restore_best_weights=False
)

# %%
history = model.fit(x_train, y_train, validation_data=(x_test, y_test), epochs=3500, callbacks=callback)
# Out:
# Epoch 1/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.5375 - loss: 0.6689 - val_accuracy: 0.3500 - val_loss: 0.7372
# Epoch 2/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.5375 - loss: 0.6687 - val_accuracy: 0.3500 - val_loss: 0.7391
# Epoch 3/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.5375 - loss: 0.6679 - val_accuracy: 0.3500 - val_loss: 0.7397
# Epoch 4/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.5375 - loss: 0.6673 - val_accuracy: 0.3500 - val_loss: 0.7404
# Epoch 5/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.5375 - loss: 0.6667 - val_accuracy: 0.3500 - val_loss: 0.7406
# Epoch 6/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.5375 - loss: 0.6662 - val_accuracy: 0.3500 - val_loss: 0.7401
# Epoch 7/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.5375 - loss: 0.6656 - val_accuracy: 0.3500 - val_loss: 0.7399
# Epoch 8/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.5375 - loss: 0.6650 - val_accuracy: 0.3500 - val_loss: 0.7404
# Epoch 9/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.5375 - loss: 0.6644 - val_accuracy: 0.3500 - val_loss: 0.7401
# Epoch 10/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.5375 - loss: 0.6640 - val_accuracy: 0.3500 - val_loss: 0.7395
# Epoch 11/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.5375 - loss: 0.6634 - val_accuracy: 0.3500 - val_loss: 0.7389
# Epoch 12/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.5375 - loss: 0.6630 - val_accuracy: 0.3500 - val_loss: 0.7389
# Epoch 13/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.5375 - loss: 0.6622 - val_accuracy: 0.3500 - val_loss: 0.7396
# Epoch 14/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.5375 - loss: 0.6620 - val_accuracy: 0.3500 - val_loss: 0.7401
# Epoch 15/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.5375 - loss: 0.6611 - val_accuracy: 0.3500 - val_loss: 0.7391
# Epoch 16/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.5375 - loss: 0.6605 - val_accuracy: 0.3500 - val_loss: 0.7377
# Epoch 17/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.5375 - loss: 0.6600 - val_accuracy: 0.3500 - val_loss: 0.7363
# Epoch 18/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.5375 - loss: 0.6596 - val_accuracy: 0.3500 - val_loss: 0.7344
# Epoch 19/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.5375 - loss: 0.6590 - val_accuracy: 0.3500 - val_loss: 0.7330
# Epoch 20/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.5375 - loss: 0.6584 - val_accuracy: 0.3500 - val_loss: 0.7320
# Epoch 21/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.5375 - loss: 0.6579 - val_accuracy: 0.3500 - val_loss: 0.7318
# Epoch 22/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.5375 - loss: 0.6576 - val_accuracy: 0.3500 - val_loss: 0.7310
# Epoch 23/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.5375 - loss: 0.6567 - val_accuracy: 0.3500 - val_loss: 0.7329
# Epoch 24/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.5375 - loss: 0.6558 - val_accuracy: 0.3500 - val_loss: 0.7347
# Epoch 25/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.5375 - loss: 0.6551 - val_accuracy: 0.3500 - val_loss: 0.7370
# Epoch 26/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.5375 - loss: 0.6543 - val_accuracy: 0.3500 - val_loss: 0.7404
# Epoch 27/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.5375 - loss: 0.6543 - val_accuracy: 0.3500 - val_loss: 0.7443
# Epoch 28/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.5375 - loss: 0.6539 - val_accuracy: 0.3500 - val_loss: 0.7462
# Epoch 29/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.5375 - loss: 0.6527 - val_accuracy: 0.3500 - val_loss: 0.7459
# Epoch 30/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.5375 - loss: 0.6521 - val_accuracy: 0.3500 - val_loss: 0.7448
# Epoch 31/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.5375 - loss: 0.6514 - val_accuracy: 0.3500 - val_loss: 0.7430
# Epoch 32/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.5375 - loss: 0.6508 - val_accuracy: 0.3500 - val_loss: 0.7415
# Epoch 33/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.5375 - loss: 0.6499 - val_accuracy: 0.3500 - val_loss: 0.7412
# Epoch 34/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.5375 - loss: 0.6491 - val_accuracy: 0.3500 - val_loss: 0.7398
# Epoch 35/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.5375 - loss: 0.6484 - val_accuracy: 0.3500 - val_loss: 0.7389
# Epoch 36/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.5375 - loss: 0.6478 - val_accuracy: 0.3500 - val_loss: 0.7389
# Epoch 37/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.5375 - loss: 0.6469 - val_accuracy: 0.3500 - val_loss: 0.7375
# Epoch 38/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.5375 - loss: 0.6464 - val_accuracy: 0.3500 - val_loss: 0.7380
# Epoch 39/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.5375 - loss: 0.6453 - val_accuracy: 0.3500 - val_loss: 0.7373
# Epoch 40/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.5375 - loss: 0.6446 - val_accuracy: 0.3500 - val_loss: 0.7369
# Epoch 41/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.5500 - loss: 0.6438 - val_accuracy: 0.3500 - val_loss: 0.7355
# Epoch 42/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.5625 - loss: 0.6429 - val_accuracy: 0.3500 - val_loss: 0.7365
# Epoch 43/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.5625 - loss: 0.6420 - val_accuracy: 0.3500 - val_loss: 0.7366
# Epoch 44/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.5625 - loss: 0.6414 - val_accuracy: 0.3500 - val_loss: 0.7382
# Epoch 45/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.5500 - loss: 0.6405 - val_accuracy: 0.3500 - val_loss: 0.7389
# Epoch 46/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.5625 - loss: 0.6398 - val_accuracy: 0.3500 - val_loss: 0.7401
# Epoch 47/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.5750 - loss: 0.6389 - val_accuracy: 0.3500 - val_loss: 0.7407
# Epoch 48/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.5750 - loss: 0.6383 - val_accuracy: 0.3500 - val_loss: 0.7393
# Epoch 49/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.5750 - loss: 0.6372 - val_accuracy: 0.3500 - val_loss: 0.7401
# Epoch 50/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.5750 - loss: 0.6365 - val_accuracy: 0.3500 - val_loss: 0.7389
# Epoch 51/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.5750 - loss: 0.6355 - val_accuracy: 0.3500 - val_loss: 0.7379
# Epoch 52/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.5750 - loss: 0.6346 - val_accuracy: 0.3500 - val_loss: 0.7363
# Epoch 53/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.5750 - loss: 0.6337 - val_accuracy: 0.3500 - val_loss: 0.7369
# Epoch 54/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.5750 - loss: 0.6326 - val_accuracy: 0.3500 - val_loss: 0.7359
# Epoch 55/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.5875 - loss: 0.6317 - val_accuracy: 0.3500 - val_loss: 0.7340
# Epoch 56/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.6000 - loss: 0.6309 - val_accuracy: 0.3500 - val_loss: 0.7313
# Epoch 57/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.6125 - loss: 0.6297 - val_accuracy: 0.3500 - val_loss: 0.7288
# Epoch 58/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.6125 - loss: 0.6293 - val_accuracy: 0.3500 - val_loss: 0.7259
# Epoch 59/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.6250 - loss: 0.6282 - val_accuracy: 0.3500 - val_loss: 0.7278
# Epoch 60/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.6125 - loss: 0.6267 - val_accuracy: 0.3500 - val_loss: 0.7288
# Epoch 61/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.6125 - loss: 0.6259 - val_accuracy: 0.3500 - val_loss: 0.7291
# Epoch 62/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.6250 - loss: 0.6248 - val_accuracy: 0.3500 - val_loss: 0.7299
# Epoch 63/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.6250 - loss: 0.6236 - val_accuracy: 0.3500 - val_loss: 0.7301
# Epoch 64/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.6375 - loss: 0.6226 - val_accuracy: 0.3500 - val_loss: 0.7300
# Epoch 65/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.6250 - loss: 0.6216 - val_accuracy: 0.3500 - val_loss: 0.7315
# Epoch 66/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.6250 - loss: 0.6207 - val_accuracy: 0.4000 - val_loss: 0.7317
# Epoch 67/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.6375 - loss: 0.6197 - val_accuracy: 0.4000 - val_loss: 0.7294
# Epoch 68/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.6375 - loss: 0.6183 - val_accuracy: 0.4000 - val_loss: 0.7292
# Epoch 69/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.6250 - loss: 0.6175 - val_accuracy: 0.4500 - val_loss: 0.7262
# Epoch 70/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.6375 - loss: 0.6163 - val_accuracy: 0.4500 - val_loss: 0.7255
# Epoch 71/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.6625 - loss: 0.6154 - val_accuracy: 0.4500 - val_loss: 0.7236
# Epoch 72/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.6625 - loss: 0.6142 - val_accuracy: 0.4500 - val_loss: 0.7242
# Epoch 73/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.6625 - loss: 0.6130 - val_accuracy: 0.4500 - val_loss: 0.7234
# Epoch 74/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.6625 - loss: 0.6118 - val_accuracy: 0.4500 - val_loss: 0.7208
# Epoch 75/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.6750 - loss: 0.6110 - val_accuracy: 0.4500 - val_loss: 0.7178
# Epoch 76/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.6750 - loss: 0.6100 - val_accuracy: 0.4500 - val_loss: 0.7165
# Epoch 77/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.6750 - loss: 0.6085 - val_accuracy: 0.4500 - val_loss: 0.7173
# Epoch 78/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.6750 - loss: 0.6071 - val_accuracy: 0.4500 - val_loss: 0.7192
# Epoch 79/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.6625 - loss: 0.6071 - val_accuracy: 0.4500 - val_loss: 0.7217
# Epoch 80/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.6750 - loss: 0.6050 - val_accuracy: 0.4500 - val_loss: 0.7206
# Epoch 81/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.6750 - loss: 0.6038 - val_accuracy: 0.4500 - val_loss: 0.7147
# Epoch 82/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.6875 - loss: 0.6025 - val_accuracy: 0.4500 - val_loss: 0.7121
# Epoch 83/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.6875 - loss: 0.6013 - val_accuracy: 0.4500 - val_loss: 0.7084
# Epoch 84/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.7000 - loss: 0.6002 - val_accuracy: 0.5000 - val_loss: 0.7040
# Epoch 85/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.7625 - loss: 0.5998 - val_accuracy: 0.5000 - val_loss: 0.7022
# Epoch 86/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.7625 - loss: 0.5987 - val_accuracy: 0.5000 - val_loss: 0.6995
# Epoch 87/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.7750 - loss: 0.5973 - val_accuracy: 0.5000 - val_loss: 0.6984
# Epoch 88/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.7750 - loss: 0.5967 - val_accuracy: 0.5000 - val_loss: 0.6940
# Epoch 89/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.7750 - loss: 0.5952 - val_accuracy: 0.5000 - val_loss: 0.6915
# Epoch 90/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.7875 - loss: 0.5938 - val_accuracy: 0.5000 - val_loss: 0.6897
# Epoch 91/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.7875 - loss: 0.5927 - val_accuracy: 0.5000 - val_loss: 0.6899
# Epoch 92/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.7750 - loss: 0.5920 - val_accuracy: 0.4500 - val_loss: 0.6938
# Epoch 93/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.7625 - loss: 0.5898 - val_accuracy: 0.4500 - val_loss: 0.6960
# Epoch 94/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.7625 - loss: 0.5885 - val_accuracy: 0.5000 - val_loss: 0.6997
# Epoch 95/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.7375 - loss: 0.5870 - val_accuracy: 0.5000 - val_loss: 0.7045
# Epoch 96/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.6875 - loss: 0.5859 - val_accuracy: 0.4500 - val_loss: 0.7089
# Epoch 97/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.6875 - loss: 0.5857 - val_accuracy: 0.4500 - val_loss: 0.7141
# Epoch 98/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.6875 - loss: 0.5836 - val_accuracy: 0.4500 - val_loss: 0.7130
# Epoch 99/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.6875 - loss: 0.5821 - val_accuracy: 0.4500 - val_loss: 0.7141
# Epoch 100/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.7000 - loss: 0.5811 - val_accuracy: 0.4500 - val_loss: 0.7135
# Epoch 101/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.7375 - loss: 0.5800 - val_accuracy: 0.4500 - val_loss: 0.7111
# Epoch 102/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.7375 - loss: 0.5784 - val_accuracy: 0.4500 - val_loss: 0.7091
# Epoch 103/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.7375 - loss: 0.5768 - val_accuracy: 0.4500 - val_loss: 0.7088
# Epoch 104/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.7375 - loss: 0.5756 - val_accuracy: 0.4500 - val_loss: 0.7073
# Epoch 105/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.7375 - loss: 0.5743 - val_accuracy: 0.4500 - val_loss: 0.7069
# Epoch 106/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.7375 - loss: 0.5738 - val_accuracy: 0.4500 - val_loss: 0.7066
# Epoch 107/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.7375 - loss: 0.5718 - val_accuracy: 0.4500 - val_loss: 0.7009
# Epoch 108/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.7750 - loss: 0.5710 - val_accuracy: 0.5500 - val_loss: 0.6961
# Epoch 109/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.8000 - loss: 0.5697 - val_accuracy: 0.5500 - val_loss: 0.6941
# Epoch 110/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.8000 - loss: 0.5686 - val_accuracy: 0.5500 - val_loss: 0.6937
# Epoch 111/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.8000 - loss: 0.5673 - val_accuracy: 0.5500 - val_loss: 0.6915
# Epoch 112/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.8000 - loss: 0.5659 - val_accuracy: 0.5500 - val_loss: 0.6921
# Epoch 113/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.7875 - loss: 0.5647 - val_accuracy: 0.5500 - val_loss: 0.6917
# Epoch 114/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.7875 - loss: 0.5632 - val_accuracy: 0.5500 - val_loss: 0.6962
# Epoch 115/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.7875 - loss: 0.5615 - val_accuracy: 0.5000 - val_loss: 0.6975
# Epoch 116/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.7750 - loss: 0.5607 - val_accuracy: 0.4500 - val_loss: 0.6984
# Epoch 117/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.7750 - loss: 0.5592 - val_accuracy: 0.4500 - val_loss: 0.7012
# Epoch 118/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.7500 - loss: 0.5577 - val_accuracy: 0.4500 - val_loss: 0.7035
# Epoch 119/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.7500 - loss: 0.5566 - val_accuracy: 0.4500 - val_loss: 0.7051
# Epoch 120/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.7500 - loss: 0.5555 - val_accuracy: 0.4500 - val_loss: 0.7064
# Epoch 121/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.7500 - loss: 0.5548 - val_accuracy: 0.4500 - val_loss: 0.7040
# Epoch 122/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.7500 - loss: 0.5533 - val_accuracy: 0.4500 - val_loss: 0.7067
# Epoch 123/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.7500 - loss: 0.5517 - val_accuracy: 0.4500 - val_loss: 0.7059
# Epoch 124/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.7500 - loss: 0.5508 - val_accuracy: 0.5000 - val_loss: 0.7028
# Epoch 125/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.7500 - loss: 0.5490 - val_accuracy: 0.5000 - val_loss: 0.7020
# Epoch 126/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.7500 - loss: 0.5476 - val_accuracy: 0.5000 - val_loss: 0.7035
# Epoch 127/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.7750 - loss: 0.5469 - val_accuracy: 0.5000 - val_loss: 0.7066
# Epoch 128/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.7625 - loss: 0.5459 - val_accuracy: 0.5000 - val_loss: 0.7087
# Epoch 129/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.7625 - loss: 0.5445 - val_accuracy: 0.4500 - val_loss: 0.7103
# Epoch 130/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.7625 - loss: 0.5436 - val_accuracy: 0.4500 - val_loss: 0.7059
# Epoch 131/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.7500 - loss: 0.5421 - val_accuracy: 0.4500 - val_loss: 0.7063
# Epoch 132/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.7500 - loss: 0.5410 - val_accuracy: 0.4500 - val_loss: 0.7029
# Epoch 133/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.7500 - loss: 0.5389 - val_accuracy: 0.4500 - val_loss: 0.6960
# Epoch 134/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.7625 - loss: 0.5373 - val_accuracy: 0.5500 - val_loss: 0.6869
# Epoch 135/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.8000 - loss: 0.5358 - val_accuracy: 0.5500 - val_loss: 0.6783
# Epoch 136/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.7875 - loss: 0.5347 - val_accuracy: 0.5500 - val_loss: 0.6718
# Epoch 137/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.8250 - loss: 0.5353 - val_accuracy: 0.5500 - val_loss: 0.6681
# Epoch 138/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.8500 - loss: 0.5331 - val_accuracy: 0.5500 - val_loss: 0.6717
# Epoch 139/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.8375 - loss: 0.5315 - val_accuracy: 0.5500 - val_loss: 0.6793
# Epoch 140/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.8000 - loss: 0.5300 - val_accuracy: 0.5500 - val_loss: 0.6858
# Epoch 141/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.7875 - loss: 0.5294 - val_accuracy: 0.5500 - val_loss: 0.6960
# Epoch 142/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.8000 - loss: 0.5276 - val_accuracy: 0.5500 - val_loss: 0.6983
# Epoch 143/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.8125 - loss: 0.5263 - val_accuracy: 0.5000 - val_loss: 0.6962
# Epoch 144/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.8000 - loss: 0.5256 - val_accuracy: 0.5500 - val_loss: 0.6924
# Epoch 145/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.7875 - loss: 0.5238 - val_accuracy: 0.5500 - val_loss: 0.6861
# Epoch 146/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.7875 - loss: 0.5226 - val_accuracy: 0.5500 - val_loss: 0.6812
# Epoch 147/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.8000 - loss: 0.5220 - val_accuracy: 0.5500 - val_loss: 0.6783
# Epoch 148/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.8000 - loss: 0.5203 - val_accuracy: 0.5500 - val_loss: 0.6787
# Epoch 149/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.7875 - loss: 0.5191 - val_accuracy: 0.5500 - val_loss: 0.6773
# Epoch 150/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.7875 - loss: 0.5185 - val_accuracy: 0.5500 - val_loss: 0.6690
# Epoch 151/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.8375 - loss: 0.5162 - val_accuracy: 0.5500 - val_loss: 0.6699
# Epoch 152/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.8250 - loss: 0.5153 - val_accuracy: 0.5500 - val_loss: 0.6747
# Epoch 153/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.7875 - loss: 0.5133 - val_accuracy: 0.5500 - val_loss: 0.6785
# Epoch 154/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.7875 - loss: 0.5119 - val_accuracy: 0.5500 - val_loss: 0.6817
# Epoch 155/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.7875 - loss: 0.5113 - val_accuracy: 0.5500 - val_loss: 0.6856
# Epoch 156/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.7875 - loss: 0.5101 - val_accuracy: 0.5500 - val_loss: 0.6865
# Epoch 157/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.7875 - loss: 0.5088 - val_accuracy: 0.5500 - val_loss: 0.6843
# Epoch 158/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.7875 - loss: 0.5070 - val_accuracy: 0.5500 - val_loss: 0.6812
# Epoch 159/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.8125 - loss: 0.5057 - val_accuracy: 0.5500 - val_loss: 0.6765
# Epoch 160/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.8250 - loss: 0.5047 - val_accuracy: 0.5500 - val_loss: 0.6713
# Epoch 161/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.8500 - loss: 0.5033 - val_accuracy: 0.5500 - val_loss: 0.6711
# Epoch 162/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.8375 - loss: 0.5026 - val_accuracy: 0.5500 - val_loss: 0.6742
# Epoch 163/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.8250 - loss: 0.5009 - val_accuracy: 0.5500 - val_loss: 0.6723
# Epoch 164/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.8375 - loss: 0.4997 - val_accuracy: 0.5500 - val_loss: 0.6728
# Epoch 165/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.8375 - loss: 0.4985 - val_accuracy: 0.5500 - val_loss: 0.6743
# Epoch 166/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.8375 - loss: 0.4969 - val_accuracy: 0.5500 - val_loss: 0.6765
# Epoch 167/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.8125 - loss: 0.4959 - val_accuracy: 0.5500 - val_loss: 0.6809
# Epoch 168/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.8125 - loss: 0.4946 - val_accuracy: 0.5500 - val_loss: 0.6822
# Epoch 169/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.8125 - loss: 0.4935 - val_accuracy: 0.5500 - val_loss: 0.6823
# Epoch 170/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.8125 - loss: 0.4926 - val_accuracy: 0.5500 - val_loss: 0.6808
# Epoch 171/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.8250 - loss: 0.4909 - val_accuracy: 0.5500 - val_loss: 0.6759
# Epoch 172/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.8250 - loss: 0.4898 - val_accuracy: 0.5500 - val_loss: 0.6736
# Epoch 173/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.8250 - loss: 0.4883 - val_accuracy: 0.5500 - val_loss: 0.6739
# Epoch 174/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.8375 - loss: 0.4876 - val_accuracy: 0.5500 - val_loss: 0.6700
# Epoch 175/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.8500 - loss: 0.4865 - val_accuracy: 0.5500 - val_loss: 0.6706
# Epoch 176/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.8375 - loss: 0.4859 - val_accuracy: 0.5500 - val_loss: 0.6731
# Epoch 177/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.8375 - loss: 0.4843 - val_accuracy: 0.5500 - val_loss: 0.6739
# Epoch 178/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.8250 - loss: 0.4831 - val_accuracy: 0.5500 - val_loss: 0.6737
# Epoch 179/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.8375 - loss: 0.4815 - val_accuracy: 0.5500 - val_loss: 0.6683
# Epoch 180/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.8500 - loss: 0.4808 - val_accuracy: 0.6000 - val_loss: 0.6626
# Epoch 181/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.8625 - loss: 0.4800 - val_accuracy: 0.6000 - val_loss: 0.6533
# Epoch 182/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.8750 - loss: 0.4783 - val_accuracy: 0.6000 - val_loss: 0.6525
# Epoch 183/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.8750 - loss: 0.4772 - val_accuracy: 0.6000 - val_loss: 0.6552
# Epoch 184/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.8625 - loss: 0.4769 - val_accuracy: 0.6000 - val_loss: 0.6566
# Epoch 185/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.8750 - loss: 0.4748 - val_accuracy: 0.6000 - val_loss: 0.6589
# Epoch 186/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.8625 - loss: 0.4736 - val_accuracy: 0.6000 - val_loss: 0.6644
# Epoch 187/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.8375 - loss: 0.4723 - val_accuracy: 0.5500 - val_loss: 0.6677
# Epoch 188/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.8375 - loss: 0.4716 - val_accuracy: 0.5500 - val_loss: 0.6701
# Epoch 189/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.8375 - loss: 0.4702 - val_accuracy: 0.5500 - val_loss: 0.6650
# Epoch 190/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.8500 - loss: 0.4699 - val_accuracy: 0.5500 - val_loss: 0.6655
# Epoch 191/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.8625 - loss: 0.4683 - val_accuracy: 0.5500 - val_loss: 0.6612
# Epoch 192/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.8750 - loss: 0.4665 - val_accuracy: 0.6000 - val_loss: 0.6556
# Epoch 193/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.8750 - loss: 0.4656 - val_accuracy: 0.6000 - val_loss: 0.6549
# Epoch 194/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.8750 - loss: 0.4644 - val_accuracy: 0.6000 - val_loss: 0.6496
# Epoch 195/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.8750 - loss: 0.4635 - val_accuracy: 0.6000 - val_loss: 0.6494
# Epoch 196/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.8625 - loss: 0.4618 - val_accuracy: 0.6000 - val_loss: 0.6540
# Epoch 197/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.8750 - loss: 0.4609 - val_accuracy: 0.6000 - val_loss: 0.6598
# Epoch 198/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.8625 - loss: 0.4597 - val_accuracy: 0.6000 - val_loss: 0.6641
# Epoch 199/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.8625 - loss: 0.4588 - val_accuracy: 0.6000 - val_loss: 0.6646
# Epoch 200/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.8625 - loss: 0.4572 - val_accuracy: 0.6000 - val_loss: 0.6710
# Epoch 201/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.8625 - loss: 0.4569 - val_accuracy: 0.6000 - val_loss: 0.6754
# Epoch 202/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.8625 - loss: 0.4567 - val_accuracy: 0.6000 - val_loss: 0.6760
# Epoch 203/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.8625 - loss: 0.4551 - val_accuracy: 0.6000 - val_loss: 0.6660
# Epoch 204/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.8625 - loss: 0.4550 - val_accuracy: 0.6000 - val_loss: 0.6547
# Epoch 205/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.8750 - loss: 0.4523 - val_accuracy: 0.6000 - val_loss: 0.6529
# Epoch 206/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.8625 - loss: 0.4510 - val_accuracy: 0.6000 - val_loss: 0.6497
# Epoch 207/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.8750 - loss: 0.4498 - val_accuracy: 0.7000 - val_loss: 0.6462
# Epoch 208/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.8750 - loss: 0.4490 - val_accuracy: 0.7000 - val_loss: 0.6460
# Epoch 209/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.8750 - loss: 0.4491 - val_accuracy: 0.7000 - val_loss: 0.6451
# Epoch 210/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.8750 - loss: 0.4481 - val_accuracy: 0.7000 - val_loss: 0.6463
# Epoch 211/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.8750 - loss: 0.4462 - val_accuracy: 0.7000 - val_loss: 0.6435
# Epoch 212/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.8750 - loss: 0.4449 - val_accuracy: 0.6500 - val_loss: 0.6458
# Epoch 213/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.8750 - loss: 0.4437 - val_accuracy: 0.6000 - val_loss: 0.6475
# Epoch 214/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.8750 - loss: 0.4428 - val_accuracy: 0.6000 - val_loss: 0.6529
# Epoch 215/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.8625 - loss: 0.4417 - val_accuracy: 0.6000 - val_loss: 0.6574
# Epoch 216/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.8750 - loss: 0.4418 - val_accuracy: 0.6000 - val_loss: 0.6593
# Epoch 217/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.8750 - loss: 0.4406 - val_accuracy: 0.6000 - val_loss: 0.6513
# Epoch 218/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.8625 - loss: 0.4396 - val_accuracy: 0.6000 - val_loss: 0.6496
# Epoch 219/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.8750 - loss: 0.4385 - val_accuracy: 0.6000 - val_loss: 0.6517
# Epoch 220/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.8625 - loss: 0.4365 - val_accuracy: 0.6000 - val_loss: 0.6602
# Epoch 221/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.8625 - loss: 0.4355 - val_accuracy: 0.5500 - val_loss: 0.6681
# Epoch 222/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.8500 - loss: 0.4354 - val_accuracy: 0.5500 - val_loss: 0.6742
# Epoch 223/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.8625 - loss: 0.4341 - val_accuracy: 0.5500 - val_loss: 0.6718
# Epoch 224/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.8500 - loss: 0.4328 - val_accuracy: 0.5500 - val_loss: 0.6665
# Epoch 225/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.8625 - loss: 0.4314 - val_accuracy: 0.6000 - val_loss: 0.6594
# Epoch 226/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.8625 - loss: 0.4307 - val_accuracy: 0.6000 - val_loss: 0.6477
# Epoch 227/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.8625 - loss: 0.4295 - val_accuracy: 0.6000 - val_loss: 0.6438
# Epoch 228/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.8750 - loss: 0.4293 - val_accuracy: 0.6000 - val_loss: 0.6435
# Epoch 229/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.8625 - loss: 0.4287 - val_accuracy: 0.6000 - val_loss: 0.6527
# Epoch 230/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.8625 - loss: 0.4263 - val_accuracy: 0.6000 - val_loss: 0.6501
# Epoch 231/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.8625 - loss: 0.4253 - val_accuracy: 0.6000 - val_loss: 0.6488
# Epoch 232/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.8625 - loss: 0.4246 - val_accuracy: 0.6000 - val_loss: 0.6545
# Epoch 233/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.8625 - loss: 0.4232 - val_accuracy: 0.6000 - val_loss: 0.6555
# Epoch 234/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.8625 - loss: 0.4231 - val_accuracy: 0.6000 - val_loss: 0.6599
# Epoch 235/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.8750 - loss: 0.4218 - val_accuracy: 0.6000 - val_loss: 0.6578
# Epoch 236/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.8750 - loss: 0.4212 - val_accuracy: 0.6000 - val_loss: 0.6591
# Epoch 237/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.8625 - loss: 0.4202 - val_accuracy: 0.7000 - val_loss: 0.6502
# Epoch 238/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.8625 - loss: 0.4186 - val_accuracy: 0.7000 - val_loss: 0.6509
# Epoch 239/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.8750 - loss: 0.4174 - val_accuracy: 0.7000 - val_loss: 0.6483
# Epoch 240/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.8750 - loss: 0.4171 - val_accuracy: 0.7000 - val_loss: 0.6399
# Epoch 241/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.8750 - loss: 0.4168 - val_accuracy: 0.7000 - val_loss: 0.6343
# Epoch 242/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.8750 - loss: 0.4154 - val_accuracy: 0.7000 - val_loss: 0.6360
# Epoch 243/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.8750 - loss: 0.4153 - val_accuracy: 0.7000 - val_loss: 0.6429
# Epoch 244/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.8750 - loss: 0.4138 - val_accuracy: 0.7000 - val_loss: 0.6419
# Epoch 245/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.8750 - loss: 0.4130 - val_accuracy: 0.7000 - val_loss: 0.6427
# Epoch 246/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.8750 - loss: 0.4117 - val_accuracy: 0.7000 - val_loss: 0.6415
# Epoch 247/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.8750 - loss: 0.4102 - val_accuracy: 0.7000 - val_loss: 0.6483
# Epoch 248/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.8750 - loss: 0.4102 - val_accuracy: 0.7000 - val_loss: 0.6518
# Epoch 249/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.8750 - loss: 0.4087 - val_accuracy: 0.6500 - val_loss: 0.6581
# Epoch 250/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.8750 - loss: 0.4079 - val_accuracy: 0.7000 - val_loss: 0.6549
# Epoch 251/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.8625 - loss: 0.4076 - val_accuracy: 0.7000 - val_loss: 0.6503
# Epoch 252/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.8750 - loss: 0.4062 - val_accuracy: 0.7000 - val_loss: 0.6537
# Epoch 253/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.8750 - loss: 0.4055 - val_accuracy: 0.7000 - val_loss: 0.6548
# Epoch 254/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.8750 - loss: 0.4045 - val_accuracy: 0.6000 - val_loss: 0.6616
# Epoch 255/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.8750 - loss: 0.4033 - val_accuracy: 0.6000 - val_loss: 0.6589
# Epoch 256/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.8750 - loss: 0.4022 - val_accuracy: 0.6000 - val_loss: 0.6568
# Epoch 257/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.8750 - loss: 0.4016 - val_accuracy: 0.6000 - val_loss: 0.6518
# Epoch 258/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.8750 - loss: 0.4011 - val_accuracy: 0.6500 - val_loss: 0.6456
# Epoch 259/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.8875 - loss: 0.3999 - val_accuracy: 0.7000 - val_loss: 0.6399
# Epoch 260/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.8875 - loss: 0.3993 - val_accuracy: 0.7000 - val_loss: 0.6369
# Epoch 261/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.8750 - loss: 0.3978 - val_accuracy: 0.7000 - val_loss: 0.6423
# Epoch 262/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.8750 - loss: 0.3972 - val_accuracy: 0.7000 - val_loss: 0.6465
# Epoch 263/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.8750 - loss: 0.3961 - val_accuracy: 0.7000 - val_loss: 0.6551
# Epoch 264/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.8750 - loss: 0.3952 - val_accuracy: 0.6000 - val_loss: 0.6598
# Epoch 265/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.8750 - loss: 0.3943 - val_accuracy: 0.6000 - val_loss: 0.6643
# Epoch 266/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.8625 - loss: 0.3935 - val_accuracy: 0.6000 - val_loss: 0.6622
# Epoch 267/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.8625 - loss: 0.3927 - val_accuracy: 0.6000 - val_loss: 0.6526
# Epoch 268/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.8625 - loss: 0.3928 - val_accuracy: 0.6500 - val_loss: 0.6430
# Epoch 269/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.8750 - loss: 0.3913 - val_accuracy: 0.7000 - val_loss: 0.6341
# Epoch 270/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.8875 - loss: 0.3917 - val_accuracy: 0.7000 - val_loss: 0.6280
# Epoch 271/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.8875 - loss: 0.3896 - val_accuracy: 0.7000 - val_loss: 0.6369
# Epoch 272/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.8750 - loss: 0.3887 - val_accuracy: 0.6000 - val_loss: 0.6557
# Epoch 273/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.8625 - loss: 0.3882 - val_accuracy: 0.6000 - val_loss: 0.6678
# Epoch 274/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.8625 - loss: 0.3880 - val_accuracy: 0.6000 - val_loss: 0.6690
# Epoch 275/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.8625 - loss: 0.3868 - val_accuracy: 0.6000 - val_loss: 0.6652
# Epoch 276/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.8625 - loss: 0.3864 - val_accuracy: 0.6500 - val_loss: 0.6583
# Epoch 277/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.8625 - loss: 0.3846 - val_accuracy: 0.6500 - val_loss: 0.6478
# Epoch 278/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.8750 - loss: 0.3837 - val_accuracy: 0.7000 - val_loss: 0.6352
# Epoch 279/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.8750 - loss: 0.3838 - val_accuracy: 0.7000 - val_loss: 0.6235
# Epoch 280/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.8875 - loss: 0.3835 - val_accuracy: 0.7000 - val_loss: 0.6276
# Epoch 281/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.8750 - loss: 0.3819 - val_accuracy: 0.7000 - val_loss: 0.6279
# Epoch 282/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.8750 - loss: 0.3810 - val_accuracy: 0.7000 - val_loss: 0.6351
# Epoch 283/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.8750 - loss: 0.3800 - val_accuracy: 0.7000 - val_loss: 0.6402
# Epoch 284/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.8750 - loss: 0.3792 - val_accuracy: 0.7000 - val_loss: 0.6503
# Epoch 285/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.8750 - loss: 0.3783 - val_accuracy: 0.7000 - val_loss: 0.6535
# Epoch 286/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.8750 - loss: 0.3778 - val_accuracy: 0.6500 - val_loss: 0.6581
# Epoch 287/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.8750 - loss: 0.3772 - val_accuracy: 0.6000 - val_loss: 0.6624
# Epoch 288/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.8750 - loss: 0.3767 - val_accuracy: 0.6000 - val_loss: 0.6593
# Epoch 289/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.8750 - loss: 0.3752 - val_accuracy: 0.6000 - val_loss: 0.6587
# Epoch 290/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.8625 - loss: 0.3748 - val_accuracy: 0.6000 - val_loss: 0.6579
# Epoch 291/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.8625 - loss: 0.3747 - val_accuracy: 0.6500 - val_loss: 0.6523
# Epoch 292/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.8625 - loss: 0.3730 - val_accuracy: 0.7000 - val_loss: 0.6519
# Epoch 293/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.8625 - loss: 0.3722 - val_accuracy: 0.6500 - val_loss: 0.6515
# Epoch 294/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.8625 - loss: 0.3714 - val_accuracy: 0.6500 - val_loss: 0.6554
# Epoch 295/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.8625 - loss: 0.3704 - val_accuracy: 0.6000 - val_loss: 0.6618
# Epoch 296/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.8625 - loss: 0.3704 - val_accuracy: 0.6000 - val_loss: 0.6728
# Epoch 297/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.8750 - loss: 0.3700 - val_accuracy: 0.6000 - val_loss: 0.6678
# Epoch 298/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.8750 - loss: 0.3700 - val_accuracy: 0.6500 - val_loss: 0.6535
# Epoch 299/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.8625 - loss: 0.3689 - val_accuracy: 0.6500 - val_loss: 0.6556
# Epoch 300/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.8625 - loss: 0.3667 - val_accuracy: 0.7000 - val_loss: 0.6450
# Epoch 301/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.8625 - loss: 0.3662 - val_accuracy: 0.7000 - val_loss: 0.6276
# Epoch 302/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.8875 - loss: 0.3656 - val_accuracy: 0.7000 - val_loss: 0.6162
# Epoch 303/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.8875 - loss: 0.3664 - val_accuracy: 0.7000 - val_loss: 0.6089
# Epoch 304/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.9125 - loss: 0.3668 - val_accuracy: 0.7000 - val_loss: 0.6098
# Epoch 305/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.9000 - loss: 0.3667 - val_accuracy: 0.7000 - val_loss: 0.6200
# Epoch 306/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.8875 - loss: 0.3646 - val_accuracy: 0.7000 - val_loss: 0.6290
# Epoch 307/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.8875 - loss: 0.3633 - val_accuracy: 0.7000 - val_loss: 0.6393
# Epoch 308/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.8750 - loss: 0.3630 - val_accuracy: 0.7000 - val_loss: 0.6492
# Epoch 309/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.8625 - loss: 0.3606 - val_accuracy: 0.7000 - val_loss: 0.6465
# Epoch 310/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.8750 - loss: 0.3604 - val_accuracy: 0.7000 - val_loss: 0.6495
# Epoch 311/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.8750 - loss: 0.3594 - val_accuracy: 0.7000 - val_loss: 0.6399
# Epoch 312/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.8750 - loss: 0.3590 - val_accuracy: 0.7000 - val_loss: 0.6405
# Epoch 313/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.8750 - loss: 0.3589 - val_accuracy: 0.7000 - val_loss: 0.6381
# Epoch 314/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.8750 - loss: 0.3581 - val_accuracy: 0.7000 - val_loss: 0.6454
# Epoch 315/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.8625 - loss: 0.3577 - val_accuracy: 0.7000 - val_loss: 0.6457
# Epoch 316/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.8625 - loss: 0.3561 - val_accuracy: 0.7000 - val_loss: 0.6498
# Epoch 317/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.8625 - loss: 0.3556 - val_accuracy: 0.7000 - val_loss: 0.6496
# Epoch 318/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.8625 - loss: 0.3547 - val_accuracy: 0.7000 - val_loss: 0.6527
# Epoch 319/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.8625 - loss: 0.3539 - val_accuracy: 0.7000 - val_loss: 0.6449
# Epoch 320/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.8750 - loss: 0.3534 - val_accuracy: 0.7000 - val_loss: 0.6320
# Epoch 321/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.9125 - loss: 0.3544 - val_accuracy: 0.7000 - val_loss: 0.6211
# Epoch 322/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.9125 - loss: 0.3532 - val_accuracy: 0.7000 - val_loss: 0.6250
# Epoch 323/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9125 - loss: 0.3518 - val_accuracy: 0.7000 - val_loss: 0.6344
# Epoch 324/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.8750 - loss: 0.3506 - val_accuracy: 0.7000 - val_loss: 0.6459
# Epoch 325/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.8625 - loss: 0.3513 - val_accuracy: 0.7000 - val_loss: 0.6603
# Epoch 326/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.8625 - loss: 0.3500 - val_accuracy: 0.7000 - val_loss: 0.6600
# Epoch 327/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.8625 - loss: 0.3502 - val_accuracy: 0.7000 - val_loss: 0.6517
# Epoch 328/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.8750 - loss: 0.3485 - val_accuracy: 0.7000 - val_loss: 0.6383
# Epoch 329/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.8875 - loss: 0.3478 - val_accuracy: 0.7000 - val_loss: 0.6271
# Epoch 330/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.8875 - loss: 0.3480 - val_accuracy: 0.7000 - val_loss: 0.6209
# Epoch 331/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.8875 - loss: 0.3473 - val_accuracy: 0.7000 - val_loss: 0.6236
# Epoch 332/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.8875 - loss: 0.3467 - val_accuracy: 0.7000 - val_loss: 0.6262
# Epoch 333/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.8875 - loss: 0.3458 - val_accuracy: 0.7000 - val_loss: 0.6382
# Epoch 334/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.8750 - loss: 0.3448 - val_accuracy: 0.7000 - val_loss: 0.6469
# Epoch 335/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.8750 - loss: 0.3445 - val_accuracy: 0.7000 - val_loss: 0.6546
# Epoch 336/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.8625 - loss: 0.3444 - val_accuracy: 0.7000 - val_loss: 0.6591
# Epoch 337/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.8625 - loss: 0.3429 - val_accuracy: 0.7000 - val_loss: 0.6593
# Epoch 338/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.8625 - loss: 0.3428 - val_accuracy: 0.7000 - val_loss: 0.6552
# Epoch 339/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.8750 - loss: 0.3426 - val_accuracy: 0.7000 - val_loss: 0.6494
# Epoch 340/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.8750 - loss: 0.3420 - val_accuracy: 0.7000 - val_loss: 0.6418
# Epoch 341/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.8750 - loss: 0.3414 - val_accuracy: 0.7000 - val_loss: 0.6421
# Epoch 342/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.8750 - loss: 0.3402 - val_accuracy: 0.7000 - val_loss: 0.6515
# Epoch 343/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.8625 - loss: 0.3398 - val_accuracy: 0.7000 - val_loss: 0.6609
# Epoch 344/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.8625 - loss: 0.3391 - val_accuracy: 0.6500 - val_loss: 0.6669
# Epoch 345/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.8625 - loss: 0.3387 - val_accuracy: 0.6500 - val_loss: 0.6611
# Epoch 346/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.8625 - loss: 0.3379 - val_accuracy: 0.6500 - val_loss: 0.6592
# Epoch 347/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.8750 - loss: 0.3372 - val_accuracy: 0.7000 - val_loss: 0.6511
# Epoch 348/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.8750 - loss: 0.3369 - val_accuracy: 0.7000 - val_loss: 0.6445
# Epoch 349/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.8625 - loss: 0.3366 - val_accuracy: 0.7000 - val_loss: 0.6452
# Epoch 350/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.8625 - loss: 0.3376 - val_accuracy: 0.7000 - val_loss: 0.6356
# Epoch 351/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.8750 - loss: 0.3352 - val_accuracy: 0.7000 - val_loss: 0.6410
# Epoch 352/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.8500 - loss: 0.3347 - val_accuracy: 0.7000 - val_loss: 0.6489
# Epoch 353/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.8625 - loss: 0.3349 - val_accuracy: 0.7000 - val_loss: 0.6557
# Epoch 353: early stopping

# %%
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()

# %%
plot_decision_regions(x_test, y_test, clf=model)
plt.show()
# Out:
# 9600/9600 ━━━━━━━━━━━━━━━━━━━━ 8s 850us/step
# <Axes: >

# %% [markdown]
# ## Dropout Layers

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import tensorflow
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.optimizers import Adam

# %%
x_train = np.linspace(-1, 1, 20)

# %%
y_train = np.array([-0.6561, -0.3099, -0.59035, -0.50855, -0.285,
                    -0.2443, -0.02445, 0.00135, -0.2006, 0.07475,
                    -0.1422, 0.06515, 0.15265, 0.3521, 0.28415,
                    0.5524, 0.23115, 0.20835, 0.4211, 0.60485])

# %%
x_test = np.linspace(-1, 1, 20)

# %%
y_test = np.array([-0.69415, -0.451, -0.43005, -0.4484, -0.1475,
                   -0.5019, -0.28055, 0.24595, -0.21425, -0.0286,
                   0.23415, 0.46575, 0.07955, 0.1973, 0.0719,
                   0.3639, 0.5536, 0.3365, 0.50705, 0.33435])

# %%
sns.scatterplot(x=x_train,y=y_train, c='black', label='train')
sns.scatterplot(x=x_test,y=y_test, c='red', label='test')
plt.legend()
plt.show()

# %% [markdown]
# ### Before using dropout

# %%
model = Sequential()

model.add(Dense(128, input_dim=1, activation='relu'))
model.add(Dense(128, activation='relu'))
model.add(Dense(1, activation='linear'))

adam = Adam(learning_rate=0.01)
model.compile(loss='mse', optimizer=adam, metrics=['mse'])

history = model.fit(x_train, y_train, epochs=500, validation_data=(x_test, y_test), verbose=False)
# Out:
# f:\Windows 10\Python Files\Data Science\py_venv\Lib\site-packages\keras\src\layers\core\dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
_, train_mse = model.evaluate(x_train, y_train, verbose=0)
_, test_mse = model.evaluate(x_test, y_test, verbose=0)
print(f'Train: {train_mse}, Test: {test_mse}')
# Out:
# Train: 0.004595459438860416, Test: 0.046728599816560745

# %%
y_pred = model.predict(x_test)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step

# %%
plt.figure()
plt.scatter(x_train, y_train, c='black', label='train')
plt.scatter(x_test, y_test, c='red', label='test')
plt.plot(x_test, y_test)
plt.legend()
plt.ylim((-1.5, 1.5))
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.show()

# %% [markdown]
# ## Dropout model

# %%
model = Sequential()

model.add(Dense(128, input_dim=1, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(1, activation='linear'))

adam = Adam(learning_rate=0.01)
model.compile(loss='mse', optimizer=adam, metrics=['mse'])

history = model.fit(x_train, y_train, epochs=500, validation_data=(x_test, y_test), verbose=False)
# Out:
# f:\Windows 10\Python Files\Data Science\py_venv\Lib\site-packages\keras\src\layers\core\dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
_, train_mse = model.evaluate(x_train, y_train, verbose=0)
_, test_mse = model.evaluate(x_test, y_test, verbose=0)
print(f'Train: {train_mse}, Test: {test_mse}')
# Out:
# Train: 0.013894927687942982, Test: 0.034249357879161835

# %%
y_pred = model.predict(x_test)
# Out:
# WARNING:tensorflow:5 out of the last 9604 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x000001A16B31AE80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step

# %%
plt.figure()
plt.title('p=0.2')
plt.scatter(x_train, y_train, c='black', label='train')
plt.scatter(x_test, y_test, c='red', label='test')
plt.plot(x_test, y_pred)
plt.legend()
plt.ylim((-1.5, 1.5))
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.show()

# %% [markdown]
# # Regularization for reducing overfitting

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.datasets import make_moons
import tensorflow
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.optimizers import Adam

# %%
x, y = make_moons(100, noise=0.25, random_state=2)

# %%
plt.scatter(x[:,0], x[:,1], c=y)
plt.show()

# %%
model1 = Sequential()

model1.add(Dense(128, input_dim=2, activation='relu'))
model1.add(Dense(128, activation='relu'))
model1.add(Dense(1, activation='sigmoid'))

model1.summary()
# Out:
# f:\Windows 10\Python Files\Data Science\py_venv\Lib\site-packages\keras\src\layers\core\dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_13"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_31 (Dense)                │ (None, 128)            │           384 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_32 (Dense)                │ (None, 128)            │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_33 (Dense)                │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 17,025 (66.50 KB)
#  Trainable params: 17,025 (66.50 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
adam = Adam(learning_rate=0.01)
model1.compile(loss='binary_crossentropy', optimizer=adam, metrics=['accuracy'])

history1 = model1.fit(x, y, epochs=200, validation_split=0.2, verbose=0)

# %%
plot_decision_regions(x, y.astype('int'), clf=model1, legend=2)
plt.xlim(-2,3)
plt.ylim(-1.5, 2)
plt.show()
# Out:
# 9600/9600 ━━━━━━━━━━━━━━━━━━━━ 9s 921us/step

# %%
plt.plot(history1.history['loss'])
plt.plot(history1.history['val_loss'])
plt.show()

# %% [markdown]
# ## applying regularization

# %%
model2 = Sequential()

model2.add(Dense(128, input_dim=2, activation='relu', kernel_regularizer=tensorflow.keras.regularizers.l2(0.03)))
model2.add(Dense(128, activation='relu', kernel_regularizer=tensorflow.keras.regularizers.l2(0.03)))
model2.add(Dense(1, activation='sigmoid'))

model2.summary()
# Out:
# f:\Windows 10\Python Files\Data Science\py_venv\Lib\site-packages\keras\src\layers\core\dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_14"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_34 (Dense)                │ (None, 128)            │           384 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_35 (Dense)                │ (None, 128)            │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_36 (Dense)                │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 17,025 (66.50 KB)
#  Trainable params: 17,025 (66.50 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
adam = Adam(learning_rate=0.01)
model2.compile(loss='binary_crossentropy', optimizer=adam, metrics=['accuracy'])

history2 = model2.fit(x, y, epochs=200, validation_split=0.2, verbose=0)

# %%
plot_decision_regions(x, y.astype('int'), clf=model2, legend=2)
plt.xlim(-2,3)
plt.ylim(-1.5, 2)
plt.show()
# Out:
# 9600/9600 ━━━━━━━━━━━━━━━━━━━━ 11s 1ms/step

# %%
plt.plot(history2.history['loss'])
plt.plot(history2.history['val_loss'])
plt.show()

# %%
model1_weight_layer1 = model1.get_weights()[0].reshape(256)
model2_weight_layer1 = model2.get_weights()[0].reshape(256)

# %%
sns.boxplot(model1_weight_layer1)
plt.show()

# %%
plt.boxplot(model2_weight_layer1)
plt.show()

# %%
model1_weight_layer1.max(), model1_weight_layer1.min()
# Out:
# (np.float32(1.2294253), np.float32(-1.7974412))

# %%
model2_weight_layer1.max(), model2_weight_layer1.min()
# Out:
# (np.float32(0.4071932), np.float32(-0.7867547))

# %%
sns.histplot(model1_weight_layer1, kde=True)
sns.histplot(model2_weight_layer1, kde=True)
plt.show()
